# %% [markdown]
# ## Matplotlib Playrgound

# %% [markdown]
# Documentation can be found here: https://matplotlib.org/
#
# Importing Python libraries

# %%
from matplotlib import pyplot as plt # import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### Basic Graph

# %%
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.plot(x, y, label="label", color="red", linewidth=2, linestyle="--", marker=".", markersize=10, markeredgecolor="black") # plotting

### Line Two ###
new = np.arange(0, 4.5, 0.5)
plt.plot(new[:5], new[:5]**2, "b.-", linewidth=2, label="x^2")
plt.plot(new[4:], new[4:]**2, "b.--", linewidth=2)


plt.xlabel("X Axis", fontdict={"fontname": "Times New Roman", "fontsize":10}) # x label
plt.ylabel("Y Axis", fontdict={"fontname": "Times New Roman", "fontsize":10}) # y label
plt.title("TITLE HERE", fontdict={"fontname": "Times New Roman", "fontsize":20}) # graph's title

plt.xticks(range(1,7)) # ticks on x axis
plt.yticks(range(1,17)) # ticks on y axis

plt.legend() # graph's legend will recall the label="label" argument passed into the plt.plot() function!

plt.show()

# %% [markdown]
# ### Shortcut Notation

# %%
# fmt = "[color][marker][line]"
plt.plot(x, y, "r.--", label="label", linewidth=2) 
plt.legend()
plt.show()
